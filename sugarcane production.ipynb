# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# from matplotlib import pyplot as plt

# %%
df=pd.read_csv("List of Countries by Sugarcane Production.csv")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America       768.678.382
# 1           1     India           Asia       348.448.000
# 2           2     China           Asia       123.059.739
# 3           3  Thailand           Asia        87.468.496
# 4           4  Pakistan           Asia        65.450.704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                  3.668,531        10.226.205             75.167,5
# 1                     260721         4.950.000             70.393,5
# 2                      88287         1.675.215             73.459,1
# 3                  1.264,303         1.336.575             65.442,2
# 4                     324219         1.130.820               57.879

# %% [markdown]
# #cleaning of data

# %%
df['Production (Tons)']=df['Production (Tons)'].str.replace(".","")

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare Yield(Kg/Hectare)
# 0                   3668531        10226205            751675
# 1                    260721         4950000            703935
# 2                     88287         1675215            734591
# 3                   1264303         1336575            654422
# 4                    324219         1130820             57879

# %%
df['Production per Person (Kg)']=df['Production per Person (Kg)'].str.replace('.','').str.replace(',','')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Production per Person (Kg)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[92], line 1
# ...

# %%
df['Acreage (Hectare)']=df['Acreage (Hectare)'].str.replace('.','')

# %%
df['Yield (Kg / Hectare)']=df['Yield (Kg / Hectare)'].str.replace('.','').str.replace(',','')

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production (Tons)  \
# 0           0    Brazil  South America         768678382
# 1           1     India           Asia         348448000
# 2           2     China           Asia         123059739
# 3           3  Thailand           Asia          87468496
# 4           4  Pakistan           Asia          65450704
#
#   Production per Person (Kg) Acreage (Hectare) Yield (Kg / Hectare)
# 0                    3668531          10226205               751675
# 1                     260721           4950000               703935
# 2                      88287           1675215               734591
# 3                    1264303           1336575               654422
# 4                     324219           1130820                57879

# %%
df.rename(columns={'Production (Tons)':'Production(Tons)'},inplace=True)

# %%
df.rename(columns={'Production per Person (Kg)':'Production_per_Person(Kg)'},inplace=True)	
df.rename(columns={'Acreage (Hectare)':'Acreage(Hectare)'},inplace=True)	
df.rename(columns={'Yield (Kg / Hectare)':'Yield(Kg/Hectare)'},inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent Production(Tons)  \
# 0           0    Brazil  South America        768678382
# 1           1     India           Asia        348448000
# 2           2     China           Asia        123059739
# 3           3  Thailand           Asia         87468496
# 4           4  Pakistan           Asia         65450704
#
#   Production_per_Person(Kg) Acreage(Hectare Yield(Kg/Hectare)
# 0                   3668531        10226205            751675
# 1                    260721         4950000            703935
# 2                     88287         1675215            734591
# 3                   1264303         1336575            654422
# 4                    324219         1130820             57879

# %%
df.isna().sum()
# Out:
# Unnamed: 0                   0
# Country                      0
# Continent                    0
# Production(Tons)             0
# Production_per_Person(Kg)    0
# Acreage(Hectare              1
# Yield(Kg/Hectare)            1
# dtype: int64

# %%
df[df['Acreage(Hectare'].isna()]
# Out:
#     Unnamed: 0   Country Continent Production(Tons) Production_per_Person(Kg)  \
# 99          99  Djibouti    Africa               53                        51
#
#    Acreage(Hectare Yield(Kg/Hectare)
# 99             NaN               NaN

# %%
df = df.dropna().reset_index().drop("index", axis = 1)

# %%
df
# Out:
#      Unnamed: 0    Country      Continent Production(Tons)  \
# 0             0     Brazil  South America        768678382
# 1             1      India           Asia        348448000
# 2             2      China           Asia        123059739
# 3             3   Thailand           Asia         87468496
# 4             4   Pakistan           Asia         65450704
# ..          ...        ...            ...              ...
# 97           97      Spain         Europe              394
# 98           98    Lebanon           Asia               97
# 99          100  Singapore           Asia               50
# 100         101      Samoa        Oceania               12
# 101         102      Syria           Asia                1
#
#     Production_per_Person(Kg) Acreage(Hectare Yield(Kg/Hectare)
# 0                     3668531        10226205            751675
# 1                      260721         4950000            703935
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0                   102
# Country                      102
# Continent                      6
# Production(Tons)             102
# Production_per_Person(Kg)    101
# Acreage(Hectare              101
# Yield(Kg/Hectare)            102
# dtype: int64

# %%
df.dtypes
# Out:
# Unnamed: 0                    int64
# Country                      object
# Continent                    object
# Production(Tons)             object
# Production_per_Person(Kg)    object
# Acreage(Hectare              object
# Yield(Kg/Hectare)            object
# dtype: object

# %%
df['Production(Tons)']=df['Production(Tons)'].astype(float)

# %%
df['Acreage(Hectare']=df['Acreage(Hectare'].astype(float)
df['Production_per_Person(Kg)']=df['Production_per_Person(Kg)'].astype(float)
df['Yield(Kg/Hectare)']=df['Yield(Kg/Hectare)'].astype(float)

# %%
df.head()
# Out:
#    Unnamed: 0   Country      Continent  Production(Tons)  \
# 0           0    Brazil  South America       768678382.0
# 1           1     India           Asia       348448000.0
# 2           2     China           Asia       123059739.0
# 3           3  Thailand           Asia        87468496.0
# 4           4  Pakistan           Asia        65450704.0
#
#    Production_per_Person(Kg)  Acreage(Hectare  Yield(Kg/Hectare)
# 0                  3668531.0       10226205.0           751675.0
# 1                   260721.0        4950000.0           703935.0
# 2                    88287.0        1675215.0           734591.0
# 3                  1264303.0        1336575.0           654422.0
# 4                   324219.0        1130820.0            57879.0

# %% [markdown]
# # univariate analysis

# %%
df['Continent'].unique()
# Out:
# array(['South America', 'Asia', 'North America', 'Oceania', 'Africa',
#        'Europe'], dtype=object)

# %%
df['Continent'].value_counts()
# Out:
# Continent
# Africa           38
# Asia             25
# North America    22
# South America    11
# Oceania           4
# Europe            2
# Name: count, dtype: int64

# %%
df['Continent'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Continent'>

# %%
df.describe()
# Out:
#        Unnamed: 0  Production(Tons)  Production_per_Person(Kg)  \
# count  102.000000      1.020000e+02               1.020000e+02
# mean    50.529412      1.850372e+07               4.124805e+05
# std     29.638985      8.419149e+07               8.669140e+05
# min      0.000000      1.000000e+00               0.000000e+00
# 25%     25.250000      6.251875e+04               1.075225e+04
# 50%     50.500000      1.440044e+06               8.135850e+04
# 75%     75.750000      6.426824e+06               2.828128e+05
# max    102.000000      7.686784e+08               4.816299e+06
#
#        Acreage(Hectare  Yield(Kg/Hectare)
# count     1.020000e+02       1.020000e+02
# mean      2.498981e+05       5.018502e+05
# std       1.137003e+06       3.169530e+05
# min       0.000000e+00       1.000000e+01
# 25%       1.104000e+03       2.487505e+05
# 50%       1.655800e+04       5.102500e+05
# 75%       8.047400e+04       7.198920e+05
# max       1.022620e+07       1.290493e+06

# %%
df = df.drop( "Unnamed: 0", axis = 1)

# %%
df.describe()
# Out:
#        Production(Tons)  Production_per_Person(Kg)  Acreage(Hectare  \
# count      1.020000e+02               1.020000e+02     1.020000e+02
# mean       1.850372e+07               4.124805e+05     2.498981e+05
# std        8.419149e+07               8.669140e+05     1.137003e+06
# min        1.000000e+00               0.000000e+00     0.000000e+00
# 25%        6.251875e+04               1.075225e+04     1.104000e+03
# 50%        1.440044e+06               8.135850e+04     1.655800e+04
# 75%        6.426824e+06               2.828128e+05     8.047400e+04
# max        7.686784e+08               4.816299e+06     1.022620e+07
#
#        Yield(Kg/Hectare)
# count       1.020000e+02
# mean        5.018502e+05
# std         3.169530e+05
# min         1.000000e+01
# 25%         2.487505e+05
# 50%         5.102500e+05
# 75%         7.198920e+05
# max         1.290493e+06

# %% [markdown]
# # checking outliers

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.boxplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.boxplot(df["Production_per_Person(Kg)"])
plt.title("Production_per_Person(Kg)")
plt.subplot(2,2,3)
sns.boxplot(df["Acreage(Hectare"])
plt.title("Acreage(Hectare")
plt.subplot(2,2,4)
sns.boxplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
# Out:
# Text(0.5, 1.0, 'Yield(Kg/Hectare)')

# %%
plt.figure(figsize = (10,8))
plt.subplot(2,2,1)
sns.distplot(df["Production(Tons)"])
plt.title("Production(Tons)")
plt.subplot(2,2,2)
sns.distplot(df["Production_per_Person(Kg)"])
plt.title("Production_per_Person(Kg)")
plt.subplot(2,2,3)
sns.distplot(df["Acreage(Hectare"])
plt.title("Acreage(Hectare")
plt.subplot(2,2,4)
sns.distplot(df["Yield(Kg/Hectare)"])
plt.title("Yield(Kg/Hectare)")
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_15528\473757358.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["Production(Tons)"])
# C:\Users\patel\AppData\Local\Temp\ipykernel_15528\473757358.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %%
#we are not removing outlierrs here as we want to know how much maximum production is being achieved

# %% [markdown]
# # Bivarite analysis

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                  3668531.0
# 1     India           Asia       348448000.0                   260721.0
# 2     China           Asia       123059739.0                    88287.0
# 3  Thailand           Asia        87468496.0                  1264303.0
# 4  Pakistan           Asia        65450704.0                   324219.0
#
#    Acreage(Hectare  Yield(Kg/Hectare)
# 0       10226205.0           751675.0
# 1        4950000.0           703935.0
# 2        1675215.0           734591.0
# 3        1336575.0           654422.0
# 4        1130820.0            57879.0

# %%
df["Country"].unique()
# Out:
# array(['Brazil', 'India', 'China', 'Thailand', 'Pakistan', 'Mexico',
#        'Colombia', 'Australia', 'Guatemala', 'United States of America',
#        'Indonesia', 'Philippines', 'Argentina', 'Cuba', 'Vietnam',
#        'Egypt', 'South Africa', 'Myanmar', 'Peru', 'Ecuador', 'Iran',
#        'El Salvador', 'Kenya', 'Bolivia', 'Nicaragua', 'Paraguay',
#        'Swaziland', 'Sudan', 'Honduras', 'Dominican Republic', 'Nepal',
#        'Zambia', 'Bangladesh', 'Costa Rica', 'Mauritius', 'Uganda',
#        'Zimbabwe', 'Venezuela', 'Madagascar', 'Tanzania', 'Malawi',
#        'Mozambique', 'Panama', 'Guyana', 'Congo-Kinshasa', 'Laos',
#        "Côte d'Ivoire", 'Japan', 'Fiji', 'Haiti', 'Belize', 'Jamaica',
#        'Ethiopia', 'Nigeria', 'Cameroon', 'Trinidad and Tobago',
#        'Sri Lanka', 'Senegal', 'Congo-Brazzaville', 'Cambodia', 'Angola',
#        'Burkina Faso', 'Chad', 'Morocco', 'Taiwan', 'Uruguay', 'Mali',
#        'Guinea', 'Gabon', 'Liberia', 'Burundi', 'Papua New Guinea',
# ...

# %%
max(df["Production(Tons)"])
# Out:
# 768678382.0

# %%
df_new=df[["Production(Tons)","Country"]].set_index("Country")

# %%
df_new
# Out:
#            Production(Tons)
# Country
# Brazil          768678382.0
# India           348448000.0
# China           123059739.0
# Thailand         87468496.0
# Pakistan         65450704.0
# ...                     ...
# Spain                 394.0
# Lebanon                97.0
# Singapore              50.0
# Samoa                  12.0
# Syria                   1.0
#
# [102 rows x 1 columns]

# %%
df_new["Production(Tons)percent"]=df_new["Production(Tons)"]*100/df_new["Production(Tons)"].sum()

# %%
df_new
# Out:
#            Production(Tons)  Production(Tons)percent  Production(Tons)_percent
# Country
# Brazil          768678382.0             4.072729e+01              4.072729e+01
# India           348448000.0             1.846200e+01              1.846200e+01
# China           123059739.0             6.520138e+00              6.520138e+00
# Thailand         87468496.0             4.634389e+00              4.634389e+00
# Pakistan         65450704.0             3.467809e+00              3.467809e+00
# ...                     ...                      ...                       ...
# Spain                 394.0             2.087551e-05              2.087551e-05
# Lebanon                97.0             5.139401e-06              5.139401e-06
# Singapore              50.0             2.649176e-06              2.649176e-06
# Samoa                  12.0             6.358022e-07              6.358022e-07
# Syria                   1.0             5.298352e-08              5.298352e-08
#
# ...

# %%
df_new["Production(Tons)_percent"].plot(kind = "pie", autopct = "%.2f")
# Out:
# <Axes: ylabel='Production(Tons)_percent'>

# %%
df[["Production(Tons)","Country"]].set_index("Country").sort_values("Production(Tons)",ascending=False).head(15).plot(kind="bar")
# Out:
# <Axes: xlabel='Country'>

# %%
pip install --upgrade matplotlib
# Out:
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\patel\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\patel\anaconda3\Lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\patel\\anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# Consider using the `--user` option or check the permissions.
#   Using cached matplotlib-3.9.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# ...
# Using cached matplotlib-3.9.1-cp312-cp312-win_amd64.whl (8.0 MB)
# ...

# %%
ax = sns.barplot(data = df.head(15),  x= "Country", y = "Production(Tons)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_15528\2823669880.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# # which country has highest land

# %%
df.head()
# Out:
#     Country      Continent  Production(Tons)  Production_per_Person(Kg)  \
# 0    Brazil  South America       768678382.0                  3668531.0
# 1     India           Asia       348448000.0                   260721.0
# 2     China           Asia       123059739.0                    88287.0
# 3  Thailand           Asia        87468496.0                  1264303.0
# 4  Pakistan           Asia        65450704.0                   324219.0
#
#    Acreage(Hectare  Yield(Kg/Hectare)
# 0       10226205.0           751675.0
# 1        4950000.0           703935.0
# 2        1675215.0           734591.0
# 3        1336575.0           654422.0
# 4        1130820.0            57879.0

# %%
df_acr=df.sort_values("Acreage(Hectare",ascending=False).head(15)
ax = sns.barplot(data = df_acr,  x= "Country", y = "Acreage(Hectare")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_15528\2100187128.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# # Which country has highest yield per haectare

# %%
df_highestyield=df.sort_values("Yield(Kg/Hectare)",ascending=False).head(15)
ax = sns.barplot(data = df_highestyield,  x= "Country", y = "Yield(Kg/Hectare)")
ax.set_xticklabels(ax.get_xticklabels(),rotation =90)
plt.show()
# Out:
# C:\Users\patel\AppData\Local\Temp\ipykernel_15528\2114693944.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation =90)

# %% [markdown]
# # correlation

# %%
df.corr(numeric_only=True)
# Out:
#                            Production(Tons)  Production_per_Person(Kg)  \
# Production(Tons)                   1.000000                   0.352369
# Production_per_Person(Kg)          0.352369                   1.000000
# Acreage(Hectare                    0.997550                   0.341974
# Yield(Kg/Hectare)                  0.121125                   0.226719
#
#                            Acreage(Hectare  Yield(Kg/Hectare)
# Production(Tons)                  0.997550           0.121125
# Production_per_Person(Kg)         0.341974           0.226719
# Acreage(Hectare                   1.000000           0.107826
# Yield(Kg/Hectare)                 0.107826           1.000000

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True,cmap="Greens")
# Out:
# <Axes: >

# %% [markdown]
# # do country with highest yield produce more sugarcane
